# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
os.chdir('..\..')

# %%
os.chdir('PycharmProjects/major_project/scraper/datasets')

# %%
df = pd.read_csv('test11.csv',index_col='title')

# %%
df.head()
# Out:
#                                                         price  reviews  \
# title
# AmazonBasics High-Speed Mini-HDMI (Not Micro US...     429.00    205.0
# Nokia 105 (Black)                                    1,065.00   3718.0
# Honor 7C (Blue, 3GB RAM, 32GB Storage)                    NaN   5428.0
# Honor 7C (Black, 3GB RAM, 32GB Storage)                   NaN   5428.0
# Gionee A1 Lite (Black, 3GB RAM, 32GB Storage)        6,990.00    286.0
#
#                                                     rating       company  \
# title
# AmazonBasics High-Speed Mini-HDMI (Not Micro US...     4.0  AmazonBasics
# Nokia 105 (Black)                                      4.0         Nokia
# Honor 7C (Blue, 3GB RAM, 32GB Storage)                 4.0         Honor
# Honor 7C (Black, 3GB RAM, 32GB Storage)                4.0         Honor
# Gionee A1 Lite (Black, 3GB RAM, 32GB Storage)          3.6        Gionee
#
#                                                        customerreviews  \
# title
# AmazonBasics High-Speed Mini-HDMI (Not Micro US...  4.0 out of 5 stars
# Nokia 105 (Black)                                   4.0 out of 5 stars
# Honor 7C (Blue, 3GB RAM, 32GB Storage)              4.0 out of 5 stars
# Honor 7C (Black, 3GB RAM, 32GB Storage)             4.0 out of 5 stars
# Gionee A1 Lite (Black, 3GB RAM, 32GB Storage)       3.6 out of 5 stars
#
#                                                     primaryprice  \
# title
# AmazonBasics High-Speed Mini-HDMI (Not Micro US...           NaN
# Nokia 105 (Black)                                            NaN
# Honor 7C (Blue, 3GB RAM, 32GB Storage)                       NaN
# Honor 7C (Black, 3GB RAM, 32GB Storage)                      NaN
# Gionee A1 Lite (Black, 3GB RAM, 32GB Storage)                NaN
#
#                                                            brand  \
# title
# AmazonBasics High-Speed Mini-HDMI (Not Micro US...  AmazonBasics
# Nokia 105 (Black)                                          Nokia
# Honor 7C (Blue, 3GB RAM, 32GB Storage)                     Honor
# Honor 7C (Black, 3GB RAM, 32GB Storage)                    Honor
# Gionee A1 Lite (Black, 3GB RAM, 32GB Storage)             Gionee
#
#                                                               totalreviews
# title
# AmazonBasics High-Speed Mini-HDMI (Not Micro US...    205 customer reviews
# Nokia 105 (Black)                                   3,718 customer reviews
# Honor 7C (Blue, 3GB RAM, 32GB Storage)              5,428 customer reviews
# Honor 7C (Black, 3GB RAM, 32GB Storage)             5,428 customer reviews
# Gionee A1 Lite (Black, 3GB RAM, 32GB Storage)         286 customer reviews

# %%
df.rating.plot(kind='barh',figsize=(10,18))

# %%
df.rating.value_counts().plot(kind='barh')

# %%
df.loc[:,'price']=df.price.str.replace(',','')

# %%
df.price.astype(float).plot(kind='barh',figsize=(13,10))

# %%
df.price=df.price.astype(float,True)

# %%
df.sort_values('price').price.plot(kind='bar')
